# %%
v4 without saving plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from scipy import stats
import pandas as pd

def load_iv_data(filename):
    """
    Load IV measurement data from file.
    Format: V2 V1 Current (3 columns)
    """
    data = np.loadtxt(filename)
    V2 = data[:, 0]  # Step voltage (outer loop)
    V1 = data[:, 1]  # Sweep voltage (inner loop)
    current = data[:, 2]  # Measured current
    return V2, V1, current

def find_voltages_for_current(V1_data, current_data, target_current, tolerance=None, method='interpolation'):
    """
    Find voltage values corresponding to a specific current value.
    
    Parameters:
    - V1_data: array of voltage values
    - current_data: array of current values
    - target_current: the current value to find voltages for
    - tolerance: tolerance for direct matching (if None, uses interpolation)
    - method: 'interpolation' or 'nearest'
    
    Returns:
    - voltages: array of voltage values corresponding to target_current
    """
    
    if method == 'nearest' and tolerance is not None:
        # Direct matching with tolerance
        mask = np.abs(current_data - target_current) <= tolerance
        return V1_data[mask]
    
    elif method == 'interpolation':
        # Use interpolation for more precise matching
        # Sort data by voltage for interpolation
        sort_indices = np.argsort(V1_data)
        V1_sorted = V1_data[sort_indices]
        current_sorted = current_data[sort_indices]
        
        # Check if target_current is within the range
        if target_current < np.min(current_sorted) or target_current > np.max(current_sorted):
            print(f"Warning: Target current {target_current} is outside the measured range "
                  f"[{np.min(current_sorted):.6f}, {np.max(current_sorted):.6f}]")
            return np.array([])
        
        # Interpolate to find voltage
        try:
            f = interpolate.interp1d(current_sorted, V1_sorted, kind='linear', 
                                   bounds_error=False, fill_value=np.nan)
            voltage = f(target_current)
            return np.array([voltage]) if not np.isnan(voltage) else np.array([])
        except:
            return np.array([])
    
    else:
        raise ValueError("Method must be 'interpolation' or 'nearest'")

def analyze_current_statistics(filename, target_current, tolerance=0.001, 
                             separate_by_V2=True, plot_results=True):
    """
    Analyze statistical distribution of voltages for a given current value.
    
    Parameters:
    - filename: path to the data file
    - target_current: the current value to analyze
    - tolerance: tolerance for current matching (only for nearest method)
    - separate_by_V2: whether to analyze each V2 sweep separately
    - plot_results: whether to create plots
    
    Returns:
    - results: dictionary containing statistical analysis
    """
    
    # Load data
    V2, V1, current = load_iv_data(filename)
    
    # For your data, it looks like V2 is constant (all zeros), so we need to 
    # identify measurement cycles differently
    # Assuming each cycle has the same V1 range, we'll group by cycle
    
    # Find the cycle length by looking for repeated V1 values
    unique_V1 = np.unique(V1)
    cycle_length = len(unique_V1)
    total_cycles = len(V1) // cycle_length
    
    print(f"Detected {total_cycles} measurement cycles with {cycle_length} points each")
    print(f"V1 range: [{np.min(V1):.3f}, {np.max(V1):.3f}] V")
    print(f"Current range: [{np.min(current):.6f}, {np.max(current):.6f}] A")
    
    all_voltages = []
    cycle_info = []
    
    # Analyze each measurement cycle
    for cycle_idx in range(total_cycles):
        start_idx = cycle_idx * cycle_length
        end_idx = start_idx + cycle_length
        
        if end_idx > len(V1):  # Handle incomplete last cycle
            end_idx = len(V1)
        
        V1_cycle = V1[start_idx:end_idx]
        current_cycle = current[start_idx:end_idx]
        
        # Find voltage for target current in this cycle
        voltage = find_voltages_for_current(V1_cycle, current_cycle, 
                                          target_current, method='interpolation')
        
        if len(voltage) > 0 and not np.isnan(voltage[0]):
            all_voltages.append(voltage[0])
            cycle_info.append({
                'cycle': cycle_idx,
                'voltage': voltage[0],
                'current': target_current
            })
            print(f"Cycle {cycle_idx}: Found voltage = {voltage[0]:.6f} V for current = {target_current:.6f} A")
    
    all_voltages = np.array(all_voltages)
    
    if len(all_voltages) == 0:
        print(f"No voltage values found for current = {target_current:.6f} A")
        print(f"Try a current value between {np.min(current):.6f} and {np.max(current):.6f} A")
        return None
    
    if len(all_voltages) == 1:
        print(f"Only one voltage value found. Cannot calculate variance.")
        print(f"Found voltage: {all_voltages[0]:.6f} V")
        return {
            'target_current': target_current,
            'voltages': all_voltages,
            'n_measurements': 1,
            'mean': all_voltages[0],
            'std': 0.0,
            'variance': 0.0,
            'min': all_voltages[0],
            'max': all_voltages[0],
            'median': all_voltages[0],
            'range': 0.0,
            'cv': 0.0,
            'shapiro_stat': None,
            'shapiro_p': None,
            'cycle_info': cycle_info
        }
    
    # Calculate statistics (safe for multiple values)
    mean_voltage = np.mean(all_voltages)
    
    # Safe calculation of standard deviation
    if len(all_voltages) > 1:
        std_voltage = np.std(all_voltages, ddof=1)  # Sample standard deviation
        variance = std_voltage**2
    else:
        std_voltage = 0.0
        variance = 0.0
    
    min_voltage = np.min(all_voltages)
    max_voltage = np.max(all_voltages)
    median_voltage = np.median(all_voltages)
    
    # Statistical tests (only if we have enough data)
    shapiro_stat, shapiro_p = None, None
    if len(all_voltages) >= 3:
        try:
            shapiro_stat, shapiro_p = stats.shapiro(all_voltages)
        except:
            shapiro_stat, shapiro_p = None, None
    
    results = {
        'target_current': target_current,
        'voltages': all_voltages,
        'n_measurements': len(all_voltages),
        'mean': mean_voltage,
        'std': std_voltage,
        'variance': variance,
        'min': min_voltage,
        'max': max_voltage,
        'median': median_voltage,
        'range': max_voltage - min_voltage,
        'cv': (std_voltage / mean_voltage * 100) if mean_voltage != 0 and std_voltage != 0 else 0,
        'shapiro_stat': shapiro_stat,
        'shapiro_p': shapiro_p,
        'cycle_info': cycle_info
    }
    
    # Print results
    print(f"\n=== Statistical Analysis for Current = {target_current:.6f} A ===")
    print(f"Number of measurements: {results['n_measurements']}")
    print(f"Mean voltage: {results['mean']:.6f} V")
    
    if results['n_measurements'] > 1:
        print(f"Standard deviation: ±{results['std']:.6f} V")
        print(f"Variance: {results['variance']:.8f} V²")
        print(f"Range: [{results['min']:.6f}, {results['max']:.6f}] V")
        print(f"Median: {results['median']:.6f} V")
        print(f"Coefficient of variation: {results['cv']:.2f}%")
        
        if shapiro_p is not None:
            print(f"Shapiro-Wilk normality test: p = {shapiro_p:.4f}")
            if shapiro_p > 0.05:
                print("  -> Data appears to be normally distributed (p > 0.05)")
            else:
                print("  -> Data may not be normally distributed (p ≤ 0.05)")
    else:
        print("Only one measurement found - no statistical analysis possible")
    
    # Create plots only if we have enough data and plot_results is True
    if plot_results and len(all_voltages) > 1:
        fig, axes = plt.subplots(2, 2, figsize=(12, 10))
        ax1, ax2, ax3, ax4 = axes.flatten()
        
        # Histogram
        n_bins = min(20, max(5, len(all_voltages)//3))
        ax1.hist(all_voltages, bins=n_bins, alpha=0.7, edgecolor='black', density=True)
        ax1.axvline(mean_voltage, color='red', linestyle='--', 
                   label=f'Mean: {mean_voltage:.6f} V')
        ax1.axvline(median_voltage, color='green', linestyle='--', 
                   label=f'Median: {median_voltage:.6f} V')
        ax1.set_xlabel('Voltage (V)')
        ax1.set_ylabel('Density')
        ax1.set_title(f'Histogram of Voltages for I = {target_current:.6f} A')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Box plot
        ax2.boxplot(all_voltages, vert=True)
        ax2.set_ylabel('Voltage (V)')
        ax2.set_title('Box Plot of Voltage Distribution')
        ax2.grid(True, alpha=0.3)
        
        # Q-Q plot for normality check (only if enough data)
        if len(all_voltages) >= 3:
            try:
                stats.probplot(all_voltages, dist="norm", plot=ax3)
                ax3.set_title('Q-Q Plot (Normal Distribution)')
                ax3.grid(True, alpha=0.3)
            except:
                ax3.text(0.5, 0.5, 'Not enough data for Q-Q plot', 
                        ha='center', va='center', transform=ax3.transAxes)
        else:
            ax3.text(0.5, 0.5, 'Not enough data for Q-Q plot', 
                    ha='center', va='center', transform=ax3.transAxes)
        
        # Time series plot (measurement order)
        cycle_numbers = [info['cycle'] for info in cycle_info]
        cycle_voltages = [info['voltage'] for info in cycle_info]
        
        ax4.plot(cycle_numbers, cycle_voltages, 'o-', alpha=0.7)
        ax4.axhline(mean_voltage, color='red', linestyle='--', alpha=0.7)
        
        if std_voltage > 0:
            ax4.fill_between(cycle_numbers, 
                            mean_voltage - std_voltage, 
                            mean_voltage + std_voltage, 
                            alpha=0.2, color='red', label='±1σ')
            ax4.legend()
        
        ax4.set_xlabel('Measurement Cycle')
        ax4.set_ylabel('Voltage (V)')
        ax4.set_title('Voltage vs Measurement Cycle')
        ax4.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
    
    elif plot_results and len(all_voltages) == 1:
        print("Only one data point found - cannot create statistical plots")
    
    return results

def compare_multiple_currents(filename, current_list, tolerance=0.001):
    """
    Compare statistics for multiple current values.
    """
    all_results = []
    
    for current in current_list:
        result = analyze_current_statistics(filename, current, tolerance, 
                                          plot_results=False)
        if result is not None:
            all_results.append(result)
    
    # Create comparison plot
    if len(all_results) > 1:
        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 10))
        
        currents = [r['target_current'] for r in all_results]
        means = [r['mean'] for r in all_results]
        stds = [r['std'] for r in all_results]
        variances = [r['variance'] for r in all_results]
        cvs = [r['cv'] for r in all_results]
        
        # Mean voltage vs current
        ax1.errorbar(currents, means, yerr=stds, fmt='o-', capsize=5)
        ax1.set_xlabel('Current (A)')
        ax1.set_ylabel('Mean Voltage (V)')
        ax1.set_title('Mean Voltage vs Current')
        ax1.grid(True, alpha=0.3)
        
        # Standard deviation vs current
        ax2.plot(currents, stds, 'o-')
        ax2.set_xlabel('Current (A)')
        ax2.set_ylabel('Standard Deviation (V)')
        ax2.set_title('Voltage Uncertainty vs Current')
        ax2.grid(True, alpha=0.3)
        
        # Variance vs current
        ax3.plot(currents, variances, 's-', color='red')
        ax3.set_xlabel('Current (A)')
        ax3.set_ylabel('Variance (V²)')
        ax3.set_title('Voltage Variance vs Current')
        ax3.grid(True, alpha=0.3)
        
        # Coefficient of variation
        ax4.plot(currents, cvs, '^-', color='purple')
        ax4.set_xlabel('Current (A)')
        ax4.set_ylabel('Coefficient of Variation (%)')
        ax4.set_title('Relative Uncertainty vs Current')
        ax4.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
    
    # Print comparison table
    print("\n=== Comparison Table ===")
    print(f"{'Current (A)':<12} {'Mean (V)':<12} {'Std (V)':<12} {'Variance (V²)':<15} {'CV (%)':<8} {'N':<5}")
    print("-" * 70)
    for r in all_results:
        print(f"{r['target_current']:<12.6f} {r['mean']:<12.6f} {r['std']:<12.6f} "
              f"{r['variance']:<15.8f} {r['cv']:<8.2f} {r['n_measurements']:<5}")
    
    return all_results

# Example usage - updated for your specific data
if __name__ == "__main__":
    filename = "data_IV_202507021410_iter20.txt"
    
    # First, let's check what current values are available
    V2, V1, current = load_iv_data(filename)
    print(f"Current range: [{np.min(current):.6f}, {np.max(current):.6f}] A")
    print(f"Voltage range: [{np.min(V1):.6f}, {np.max(V1):.6f}] V")
    print(f"Total data points: {len(current)}")
    
    # Suggest some good target currents based on the data range
    min_current = np.min(current)
    max_current = np.max(current)
    target_currents = np.linspace(min_current + 0.01, max_current - 0.01, 5)
    
    print(f"\nSuggested target currents: {[f'{i:.3f}' for i in target_currents]}")
    
    # Analyze a single current value
    target_current = target_currents[2]  # Middle value
    print(f"\n=== Analyzing target current: {target_current:.3f} A ===")
    
    result = analyze_current_statistics(filename, target_current, 
                                      tolerance=0.001, plot_results=True)
    
    if result is not None:
        print(f"\nFound {result['n_measurements']} voltage measurements")
        if result['n_measurements'] > 1:
            print(f"Voltage statistics: {result['mean']:.6f} ± {result['std']:.6f} V")
        else:
            print(f"Single voltage value: {result['mean']:.6f} V")
    
    # Analyze multiple currents for comparison
    print(f"\n=== Comparing Multiple Current Values ===")
    comparison_currents = target_currents[:3]  # Use first 3 values
    results = compare_multiple_currents(filename, comparison_currents)
# Out:
# Current range: [0.000563, 0.639042] A
# Voltage range: [-1.500000, -0.510000] V
# Total data points: 2000
#
# Suggested target currents: ['0.011', '0.165', '0.320', '0.474', '0.629']
#
# === Analyzing target current: 0.320 A ===
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Warning: Target current 0.3198025 is outside the measured range [0.000621, 0.318944]
# Cycle 1: Found voltage = -0.725955 V for current = 0.319802 A
# Cycle 2: Found voltage = -0.750380 V for current = 0.319802 A
# Cycle 3: Found voltage = -0.714186 V for current = 0.319802 A
# Cycle 4: Found voltage = -0.715451 V for current = 0.319802 A
# Cycle 5: Found voltage = -0.708269 V for current = 0.319802 A
# Cycle 6: Found voltage = -0.715169 V for current = 0.319802 A
# Cycle 7: Found voltage = -0.710834 V for current = 0.319802 A
# Cycle 8: Found voltage = -0.713357 V for current = 0.319802 A
# Cycle 9: Found voltage = -0.715785 V for current = 0.319802 A
# Cycle 10: Found voltage = -0.716539 V for current = 0.319802 A
# Cycle 11: Found voltage = -0.727571 V for current = 0.319802 A
# Cycle 12: Found voltage = -0.725808 V for current = 0.319802 A
# Cycle 13: Found voltage = -0.730063 V for current = 0.319802 A
# Cycle 14: Found voltage = -0.708155 V for current = 0.319802 A
# Cycle 15: Found voltage = -0.718764 V for current = 0.319802 A
# Cycle 16: Found voltage = -0.748250 V for current = 0.319802 A
# Cycle 17: Found voltage = -0.743470 V for current = 0.319802 A
# Cycle 18: Found voltage = -0.787696 V for current = 0.319802 A
# Cycle 19: Found voltage = -0.783388 V for current = 0.319802 A
#
# === Statistical Analysis for Current = 0.319802 A ===
# Number of measurements: 19
# Mean voltage: -0.729426 V
# Standard deviation: ±0.023485 V
# Variance: 0.00055153 V²
# Range: [-0.787696, -0.708155] V
# Median: -0.718764 V
# Coefficient of variation: -3.22%
# Shapiro-Wilk normality test: p = 0.0008
#   -> Data may not be normally distributed (p ≤ 0.05)
# Found 19 voltage measurements
# Voltage statistics: -0.729426 ± 0.023485 V
#
# === Comparing Multiple Current Values ===
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Cycle 0: Found voltage = -1.197386 V for current = 0.010563 A
# Cycle 1: Found voltage = -1.197149 V for current = 0.010563 A
# Cycle 2: Found voltage = -1.197594 V for current = 0.010563 A
# Cycle 3: Found voltage = -1.197274 V for current = 0.010563 A
# Cycle 4: Found voltage = -1.197432 V for current = 0.010563 A
# Cycle 5: Found voltage = -1.196327 V for current = 0.010563 A
# Cycle 6: Found voltage = -1.197481 V for current = 0.010563 A
# Cycle 7: Found voltage = -1.197078 V for current = 0.010563 A
# Cycle 8: Found voltage = -1.197686 V for current = 0.010563 A
# Cycle 9: Found voltage = -1.197197 V for current = 0.010563 A
# Cycle 10: Found voltage = -1.197422 V for current = 0.010563 A
# Cycle 11: Found voltage = -1.196912 V for current = 0.010563 A
# Cycle 12: Found voltage = -1.197768 V for current = 0.010563 A
# Cycle 13: Found voltage = -1.197366 V for current = 0.010563 A
# Cycle 14: Found voltage = -1.197355 V for current = 0.010563 A
# Cycle 15: Found voltage = -1.197481 V for current = 0.010563 A
# Cycle 16: Found voltage = -1.197986 V for current = 0.010563 A
# Cycle 17: Found voltage = -1.197596 V for current = 0.010563 A
# Cycle 18: Found voltage = -1.199409 V for current = 0.010563 A
# Cycle 19: Found voltage = -1.199694 V for current = 0.010563 A
#
# === Statistical Analysis for Current = 0.010563 A ===
# Number of measurements: 20
# Mean voltage: -1.197580 V
# Standard deviation: ±0.000758 V
# Variance: 0.00000057 V²
# Range: [-1.199694, -1.196327] V
# Median: -1.197427 V
# Coefficient of variation: -0.06%
# Shapiro-Wilk normality test: p = 0.0005
#   -> Data may not be normally distributed (p ≤ 0.05)
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Cycle 0: Found voltage = -0.943734 V for current = 0.165183 A
# Cycle 1: Found voltage = -0.978309 V for current = 0.165183 A
# Cycle 2: Found voltage = -0.983253 V for current = 0.165183 A
# Cycle 3: Found voltage = -0.963965 V for current = 0.165183 A
# Cycle 4: Found voltage = -0.966374 V for current = 0.165183 A
# Cycle 5: Found voltage = -0.951787 V for current = 0.165183 A
# Cycle 6: Found voltage = -0.959649 V for current = 0.165183 A
# Cycle 7: Found voltage = -0.959739 V for current = 0.165183 A
# Cycle 8: Found voltage = -0.958050 V for current = 0.165183 A
# Cycle 9: Found voltage = -0.963719 V for current = 0.165183 A
# Cycle 10: Found voltage = -0.964368 V for current = 0.165183 A
# Cycle 11: Found voltage = -0.967416 V for current = 0.165183 A
# Cycle 12: Found voltage = -0.969318 V for current = 0.165183 A
# Cycle 13: Found voltage = -0.962458 V for current = 0.165183 A
# Cycle 14: Found voltage = -0.962590 V for current = 0.165183 A
# Cycle 15: Found voltage = -0.963571 V for current = 0.165183 A
# Cycle 16: Found voltage = -0.977944 V for current = 0.165183 A
# Cycle 17: Found voltage = -0.990396 V for current = 0.165183 A
# Cycle 18: Found voltage = -1.005273 V for current = 0.165183 A
# Cycle 19: Found voltage = -1.007319 V for current = 0.165183 A
#
# === Statistical Analysis for Current = 0.165183 A ===
# Number of measurements: 20
# Mean voltage: -0.969962 V
# Standard deviation: ±0.016252 V
# Variance: 0.00026413 V²
# Range: [-1.007319, -0.943734] V
# Median: -0.964166 V
# Coefficient of variation: -1.68%
# Shapiro-Wilk normality test: p = 0.0251
#   -> Data may not be normally distributed (p ≤ 0.05)
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Warning: Target current 0.3198025 is outside the measured range [0.000621, 0.318944]
# Cycle 1: Found voltage = -0.725955 V for current = 0.319802 A
# Cycle 2: Found voltage = -0.750380 V for current = 0.319802 A
# Cycle 3: Found voltage = -0.714186 V for current = 0.319802 A
# Cycle 4: Found voltage = -0.715451 V for current = 0.319802 A
# Cycle 5: Found voltage = -0.708269 V for current = 0.319802 A
# Cycle 6: Found voltage = -0.715169 V for current = 0.319802 A
# Cycle 7: Found voltage = -0.710834 V for current = 0.319802 A
# Cycle 8: Found voltage = -0.713357 V for current = 0.319802 A
# Cycle 9: Found voltage = -0.715785 V for current = 0.319802 A
# Cycle 10: Found voltage = -0.716539 V for current = 0.319802 A
# Cycle 11: Found voltage = -0.727571 V for current = 0.319802 A
# Cycle 12: Found voltage = -0.725808 V for current = 0.319802 A
# Cycle 13: Found voltage = -0.730063 V for current = 0.319802 A
# Cycle 14: Found voltage = -0.708155 V for current = 0.319802 A
# Cycle 15: Found voltage = -0.718764 V for current = 0.319802 A
# Cycle 16: Found voltage = -0.748250 V for current = 0.319802 A
# Cycle 17: Found voltage = -0.743470 V for current = 0.319802 A
# Cycle 18: Found voltage = -0.787696 V for current = 0.319802 A
# Cycle 19: Found voltage = -0.783388 V for current = 0.319802 A
#
# === Statistical Analysis for Current = 0.319802 A ===
# Number of measurements: 19
# Mean voltage: -0.729426 V
# Standard deviation: ±0.023485 V
# Variance: 0.00055153 V²
# Range: [-0.787696, -0.708155] V
# Median: -0.718764 V
# Coefficient of variation: -3.22%
# Shapiro-Wilk normality test: p = 0.0008
#   -> Data may not be normally distributed (p ≤ 0.05)
# === Comparison Table ===
# Current (A)  Mean (V)     Std (V)      Variance (V²)   CV (%)   N
# ----------------------------------------------------------------------
# 0.010563     -1.197580    0.000758     0.00000057      -0.06    20
# 0.165183     -0.969962    0.016252     0.00026413      -1.68    20
# 0.319802     -0.729426    0.023485     0.00055153      -3.22    19

# %% [markdown]
# Final fixed version with plots saved

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from scipy import stats
import pandas as pd
import os

def load_iv_data(filename):
    """
    Load IV measurement data from file.
    Format: V2 V1 Current (3 columns)
    """
    data = np.loadtxt(filename)
    V2 = data[:, 0]  # Step voltage (outer loop)
    V1 = data[:, 1]  # Sweep voltage (inner loop)
    current = data[:, 2]  # Measured current
    return V2, V1, current

def find_voltages_for_current(V1_data, current_data, target_current, tolerance=None, method='interpolation'):
    """
    Find voltage values corresponding to a specific current value.
    
    Parameters:
    - V1_data: array of voltage values
    - current_data: array of current values
    - target_current: the current value to find voltages for
    - tolerance: tolerance for direct matching (if None, uses interpolation)
    - method: 'interpolation' or 'nearest'
    
    Returns:
    - voltages: array of voltage values corresponding to target_current
    """
    
    if method == 'nearest' and tolerance is not None:
        # Direct matching with tolerance
        mask = np.abs(current_data - target_current) <= tolerance
        return V1_data[mask]
    
    elif method == 'interpolation':
        # Use interpolation for more precise matching
        # Sort data by voltage for interpolation
        sort_indices = np.argsort(V1_data)
        V1_sorted = V1_data[sort_indices]
        current_sorted = current_data[sort_indices]
        
        # Check if target_current is within the range
        if target_current < np.min(current_sorted) or target_current > np.max(current_sorted):
            print(f"Warning: Target current {target_current} is outside the measured range "
                  f"[{np.min(current_sorted):.6f}, {np.max(current_sorted):.6f}]")
            return np.array([])
        
        # Interpolate to find voltage
        try:
            f = interpolate.interp1d(current_sorted, V1_sorted, kind='linear', 
                                   bounds_error=False, fill_value=np.nan)
            voltage = f(target_current)
            return np.array([voltage]) if not np.isnan(voltage) else np.array([])
        except:
            return np.array([])
    
    else:
        raise ValueError("Method must be 'interpolation' or 'nearest'")

def analyze_current_statistics(filename, target_current, tolerance=0.001, 
                             plot_results=True, save_plots=False, 
                             output_dir="iv_analysis_plots"):
    """
    Analyze statistical distribution of voltages for a given current value.
    
    Parameters:
    - filename: path to the data file
    - target_current: the current value to analyze
    - tolerance: tolerance for current matching (only for nearest method)
    - plot_results: whether to display plots
    - save_plots: whether to save plots to files
    - output_dir: directory to save plots
    
    Returns:
    - results: dictionary containing statistical analysis
    """
    
    # Create output directory if saving plots
    if save_plots:
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
            print(f"Created output directory: {output_dir}")
    
    # Load data
    V2, V1, current = load_iv_data(filename)
    
    # Find the cycle length by looking for repeated V1 values
    unique_V1 = np.unique(V1)
    cycle_length = len(unique_V1)
    total_cycles = len(V1) // cycle_length
    
    print(f"Detected {total_cycles} measurement cycles with {cycle_length} points each")
    print(f"V1 range: [{np.min(V1):.3f}, {np.max(V1):.3f}] V")
    print(f"Current range: [{np.min(current):.6f}, {np.max(current):.6f}] A")
    
    all_voltages = []
    cycle_info = []
    
    # Analyze each measurement cycle
    for cycle_idx in range(total_cycles):
        start_idx = cycle_idx * cycle_length
        end_idx = start_idx + cycle_length
        
        if end_idx > len(V1):  # Handle incomplete last cycle
            end_idx = len(V1)
        
        V1_cycle = V1[start_idx:end_idx]
        current_cycle = current[start_idx:end_idx]
        
        # Find voltage for target current in this cycle
        voltage = find_voltages_for_current(V1_cycle, current_cycle, 
                                          target_current, method='interpolation')
        
        if len(voltage) > 0 and not np.isnan(voltage[0]):
            all_voltages.append(voltage[0])
            cycle_info.append({
                'cycle': cycle_idx,
                'voltage': voltage[0],
                'current': target_current
            })
            print(f"Cycle {cycle_idx}: Found voltage = {voltage[0]:.6f} V for current = {target_current:.6f} A")
    
    all_voltages = np.array(all_voltages)
    
    if len(all_voltages) == 0:
        print(f"No voltage values found for current = {target_current:.6f} A")
        print(f"Try a current value between {np.min(current):.6f} and {np.max(current):.6f} A")
        return None
    
    if len(all_voltages) == 1:
        print(f"Only one voltage value found. Cannot calculate variance.")
        print(f"Found voltage: {all_voltages[0]:.6f} V")
        return {
            'target_current': target_current,
            'voltages': all_voltages,
            'n_measurements': 1,
            'mean': all_voltages[0],
            'std': 0.0,
            'variance': 0.0,
            'min': all_voltages[0],
            'max': all_voltages[0],
            'median': all_voltages[0],
            'range': 0.0,
            'cv': 0.0,
            'shapiro_stat': None,
            'shapiro_p': None,
            'cycle_info': cycle_info
        }
    
    # Calculate statistics (safe for multiple values)
    mean_voltage = np.mean(all_voltages)
    
    # Safe calculation of standard deviation
    if len(all_voltages) > 1:
        std_voltage = np.std(all_voltages, ddof=1)  # Sample standard deviation
        variance = std_voltage**2
    else:
        std_voltage = 0.0
        variance = 0.0
    
    min_voltage = np.min(all_voltages)
    max_voltage = np.max(all_voltages)
    median_voltage = np.median(all_voltages)
    
    # Statistical tests (only if we have enough data)
    shapiro_stat, shapiro_p = None, None
    if len(all_voltages) >= 3:
        try:
            shapiro_stat, shapiro_p = stats.shapiro(all_voltages)
        except:
            shapiro_stat, shapiro_p = None, None
    
    results = {
        'target_current': target_current,
        'voltages': all_voltages,
        'n_measurements': len(all_voltages),
        'mean': mean_voltage,
        'std': std_voltage,
        'variance': variance,
        'min': min_voltage,
        'max': max_voltage,
        'median': median_voltage,
        'range': max_voltage - min_voltage,
        'cv': (std_voltage / mean_voltage * 100) if mean_voltage != 0 and std_voltage != 0 else 0,
        'shapiro_stat': shapiro_stat,
        'shapiro_p': shapiro_p,
        'cycle_info': cycle_info
    }
    
    # Print results
    print(f"\n=== Statistical Analysis for Current = {target_current:.6f} A ===")
    print(f"Number of measurements: {results['n_measurements']}")
    print(f"Mean voltage: {results['mean']:.6f} V")
    
    if results['n_measurements'] > 1:
        print(f"Standard deviation: ±{results['std']:.6f} V")
        print(f"Variance: {results['variance']:.8f} V²")
        print(f"Range: [{results['min']:.6f}, {results['max']:.6f}] V")
        print(f"Median: {results['median']:.6f} V")
        print(f"Coefficient of variation: {results['cv']:.2f}%")
        
        if shapiro_p is not None:
            print(f"Shapiro-Wilk normality test: p = {shapiro_p:.4f}")
            if shapiro_p > 0.05:
                print("  -> Data appears to be normally distributed (p > 0.05)")
            else:
                print("  -> Data may not be normally distributed (p ≤ 0.05)")
    else:
        print("Only one measurement found - no statistical analysis possible")
    
    # Create plots only if we have enough data
    if (plot_results or save_plots) and len(all_voltages) > 1:
        fig, axes = plt.subplots(2, 2, figsize=(15, 12))
        ax1, ax2, ax3, ax4 = axes.flatten()
        
        # Histogram
        n_bins = min(20, max(5, len(all_voltages)//3))
        ax1.hist(all_voltages, bins=n_bins, alpha=0.7, edgecolor='black', density=True)
        ax1.axvline(mean_voltage, color='red', linestyle='--', 
                   label=f'Mean: {mean_voltage:.6f} V')
        ax1.axvline(median_voltage, color='green', linestyle='--', 
                   label=f'Median: {median_voltage:.6f} V')
        ax1.set_xlabel('Voltage (V)')
        ax1.set_ylabel('Density')
        ax1.set_title(f'Histogram of Voltages for I = {target_current:.6f} A')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Box plot
        bp = ax2.boxplot(all_voltages, vert=True, patch_artist=True)
        bp['boxes'][0].set_facecolor('lightblue')
        ax2.set_ylabel('Voltage (V)')
        ax2.set_title('Box Plot of Voltage Distribution')
        ax2.grid(True, alpha=0.3)
        
        # Add statistics text to box plot
        stats_text = f'Mean: {mean_voltage:.6f} V\nStd: {std_voltage:.6f} V\nCV: {results["cv"]:.2f}%'
        ax2.text(0.02, 0.98, stats_text, transform=ax2.transAxes, verticalalignment='top',
                bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
        
        # Q-Q plot for normality check (only if enough data)
        if len(all_voltages) >= 3:
            try:
                stats.probplot(all_voltages, dist="norm", plot=ax3)
                ax3.set_title('Q-Q Plot (Normal Distribution)')
                ax3.grid(True, alpha=0.3)
            except:
                ax3.text(0.5, 0.5, 'Error creating Q-Q plot', 
                        ha='center', va='center', transform=ax3.transAxes)
        else:
            ax3.text(0.5, 0.5, 'Not enough data for Q-Q plot', 
                    ha='center', va='center', transform=ax3.transAxes)
        
        # Time series plot (measurement order)
        cycle_numbers = [info['cycle'] for info in cycle_info]
        cycle_voltages = [info['voltage'] for info in cycle_info]
        
        ax4.plot(cycle_numbers, cycle_voltages, 'o-', alpha=0.7, linewidth=2, markersize=6)
        ax4.axhline(mean_voltage, color='red', linestyle='--', alpha=0.7, linewidth=2)
        
        if std_voltage > 0:
            ax4.fill_between(cycle_numbers, 
                            mean_voltage - std_voltage, 
                            mean_voltage + std_voltage, 
                            alpha=0.2, color='red', label='±1σ')
            ax4.legend()
        
        ax4.set_xlabel('Measurement Cycle')
        ax4.set_ylabel('Voltage (V)')
        ax4.set_title('Voltage vs Measurement Cycle')
        ax4.grid(True, alpha=0.3)
        
        plt.tight_layout()
        
        # Save the plot if requested
        if save_plots:
            plot_filename = f"{output_dir}/voltage_analysis_I_{target_current:.6f}A.png"
            plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
            print(f"Plot saved as: {plot_filename}")
        
        if plot_results:
            plt.show()
        else:
            plt.close()
    
    elif (plot_results or save_plots) and len(all_voltages) == 1:
        print("Only one data point found - cannot create statistical plots")
    
    return results

def compare_multiple_currents(filename, current_list, tolerance=0.001, 
                            save_plots=False, output_dir="iv_analysis_plots"):
    """
    Compare statistics for multiple current values.
    """
    all_results = []
    
    # Create output directory if saving plots
    if save_plots:
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
    
    for current in current_list:
        result = analyze_current_statistics(filename, current, tolerance, 
                                          plot_results=False, save_plots=save_plots,
                                          output_dir=output_dir)
        if result is not None:
            all_results.append(result)
    
    # Create comparison plot
    if len(all_results) > 1:
        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
        
        currents = [r['target_current'] for r in all_results]
        means = [r['mean'] for r in all_results]
        stds = [r['std'] for r in all_results]
        variances = [r['variance'] for r in all_results]
        cvs = [r['cv'] for r in all_results]
        
        # Mean voltage vs current
        ax1.errorbar(currents, means, yerr=stds, fmt='o-', capsize=5, linewidth=2, markersize=8)
        ax1.set_xlabel('Current (A)')
        ax1.set_ylabel('Mean Voltage (V)')
        ax1.set_title('Mean Voltage vs Current')
        ax1.grid(True, alpha=0.3)
        
        # Standard deviation vs current
        ax2.plot(currents, stds, 'o-', linewidth=2, markersize=8, color='orange')
        ax2.set_xlabel('Current (A)')
        ax2.set_ylabel('Standard Deviation (V)')
        ax2.set_title('Voltage Uncertainty vs Current')
        ax2.grid(True, alpha=0.3)
        
        # Variance vs current
        ax3.plot(currents, variances, 's-', color='red', linewidth=2, markersize=8)
        ax3.set_xlabel('Current (A)')
        ax3.set_ylabel('Variance (V²)')
        ax3.set_title('Voltage Variance vs Current')
        ax3.grid(True, alpha=0.3)
        
        # Coefficient of variation
        ax4.plot(currents, cvs, '^-', color='purple', linewidth=2, markersize=8)
        ax4.set_xlabel('Current (A)')
        ax4.set_ylabel('Coefficient of Variation (%)')
        ax4.set_title('Relative Uncertainty vs Current')
        ax4.grid(True, alpha=0.3)
        
        plt.tight_layout()
        
        # Save comparison plot
        if save_plots:
            comparison_filename = f"{output_dir}/current_comparison.png"
            plt.savefig(comparison_filename, dpi=300, bbox_inches='tight')
            print(f"Comparison plot saved as: {comparison_filename}")
        
        plt.show()
    
    # Print comparison table
    print("\n=== Comparison Table ===")
    print(f"{'Current (A)':<12} {'Mean (V)':<12} {'Std (V)':<12} {'Variance (V²)':<15} {'CV (%)':<8} {'N':<5}")
    print("-" * 70)
    for r in all_results:
        print(f"{r['target_current']:<12.6f} {r['mean']:<12.6f} {r['std']:<12.6f} "
              f"{r['variance']:<15.8f} {r['cv']:<8.2f} {r['n_measurements']:<5}")
    
    # Save comparison table to CSV
    if save_plots:
        df_data = []
        for r in all_results:
            df_data.append({
                'Current_A': r['target_current'],
                'Mean_V': r['mean'],
                'Std_V': r['std'],
                'Variance_V2': r['variance'],
                'CV_percent': r['cv'],
                'N_measurements': r['n_measurements'],
                'Min_V': r['min'],
                'Max_V': r['max'],
                'Median_V': r['median'],
                'Range_V': r['range']
            })
        
        df = pd.DataFrame(df_data)
        csv_filename = f"{output_dir}/statistical_summary.csv"
        df.to_csv(csv_filename, index=False)
        print(f"Statistical summary saved as: {csv_filename}")
    
    return all_results

def save_voltage_data(results, output_dir="iv_analysis_plots"):
    """
    Save the extracted voltage data to text files for further analysis.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    if results is not None and 'voltages' in results:
        # Save voltage values
        voltage_filename = f"{output_dir}/voltages_I_{results['target_current']:.6f}A.txt"
        np.savetxt(voltage_filename, results['voltages'], 
                  header=f"Voltage values (V) for current = {results['target_current']:.6f} A\n"
                         f"Number of measurements: {results['n_measurements']}\n"
                         f"Mean: {results['mean']:.6f} V\n"
                         f"Std: {results['std']:.6f} V\n"
                         f"Variance: {results['variance']:.8f} V²",
                  fmt='%.8f')
        print(f"Voltage data saved as: {voltage_filename}")
        
        # Save cycle information
        if 'cycle_info' in results and results['cycle_info']:
            cycle_filename = f"{output_dir}/cycle_data_I_{results['target_current']:.6f}A.txt"
            with open(cycle_filename, 'w') as f:
                f.write("# Cycle\tVoltage(V)\tCurrent(A)\n")
                for info in results['cycle_info']:
                    f.write(f"{info['cycle']}\t{info['voltage']:.8f}\t{info['current']:.8f}\n")
            print(f"Cycle data saved as: {cycle_filename}")

# Example usage - corrected
if __name__ == "__main__":
    filename = "data_IV_202507021410_iter20.txt"
    output_directory = "iv_analysis_plots"  # Directory to save plots
    
    # First, let's check what current values are available
    V2, V1, current = load_iv_data(filename)
    print(f"Current range: [{np.min(current):.6f}, {np.max(current):.6f}] A")
    print(f"Voltage range: [{np.min(V1):.6f}, {np.max(V1):.6f}] V")
    print(f"Total data points: {len(current)}")
    
    # Suggest some good target currents based on the data range
    min_current = np.min(current)
    max_current = np.max(current)
    target_currents = np.linspace(min_current + 0.01, max_current - 0.01, 5)
    
    print(f"\nSuggested target currents: {[f'{i:.3f}' for i in target_currents]}")
    
    # Analyze a single current value with plot saving
    target_current = target_currents[2]  # Middle value
    print(f"\n=== Analyzing target current: {target_current:.3f} A ===")
    
    result = analyze_current_statistics(filename, target_current, 
                                      tolerance=0.001, plot_results=True, 
                                      save_plots=True, output_dir=output_directory)
    
    if result is not None:
        print(f"\nFound {result['n_measurements']} voltage measurements")
        if result['n_measurements'] > 1:
            print(f"Voltage statistics: {result['mean']:.6f} ± {result['std']:.6f} V")
        else:
            print(f"Single voltage value: {result['mean']:.6f} V")
        
        # Save additional data
        save_voltage_data(result, output_directory)
    
    # Analyze multiple currents for comparison with plot saving
    print(f"\n=== Comparing Multiple Current Values ===")
    comparison_currents = target_currents[:3]  # Use first 3 values
    results = compare_multiple_currents(filename, comparison_currents, 
                                      save_plots=True, output_dir=output_directory)
    
    print(f"\n=== Analysis Complete ===")
    print(f"All plots and data have been saved to the '{output_directory}' directory")
    print("Files generated:")
    print("- Individual voltage analysis plots for each current")
    print("- Comparison plot across multiple currents")
    print("- Statistical summary CSV file")
    print("- Individual voltage data text files")
# Out:
# Current range: [0.000563, 0.639042] A
# Voltage range: [-1.500000, -0.510000] V
# Total data points: 2000
#
# Suggested target currents: ['0.011', '0.165', '0.320', '0.474', '0.629']
#
# === Analyzing target current: 0.320 A ===
# Created output directory: iv_analysis_plots
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Warning: Target current 0.3198025 is outside the measured range [0.000621, 0.318944]
# Cycle 1: Found voltage = -0.725955 V for current = 0.319802 A
# Cycle 2: Found voltage = -0.750380 V for current = 0.319802 A
# Cycle 3: Found voltage = -0.714186 V for current = 0.319802 A
# Cycle 4: Found voltage = -0.715451 V for current = 0.319802 A
# Cycle 5: Found voltage = -0.708269 V for current = 0.319802 A
# Cycle 6: Found voltage = -0.715169 V for current = 0.319802 A
# Cycle 7: Found voltage = -0.710834 V for current = 0.319802 A
# Cycle 8: Found voltage = -0.713357 V for current = 0.319802 A
# Cycle 9: Found voltage = -0.715785 V for current = 0.319802 A
# Cycle 10: Found voltage = -0.716539 V for current = 0.319802 A
# Cycle 11: Found voltage = -0.727571 V for current = 0.319802 A
# Cycle 12: Found voltage = -0.725808 V for current = 0.319802 A
# Cycle 13: Found voltage = -0.730063 V for current = 0.319802 A
# Cycle 14: Found voltage = -0.708155 V for current = 0.319802 A
# Cycle 15: Found voltage = -0.718764 V for current = 0.319802 A
# Cycle 16: Found voltage = -0.748250 V for current = 0.319802 A
# Cycle 17: Found voltage = -0.743470 V for current = 0.319802 A
# Cycle 18: Found voltage = -0.787696 V for current = 0.319802 A
# Cycle 19: Found voltage = -0.783388 V for current = 0.319802 A
#
# === Statistical Analysis for Current = 0.319802 A ===
# Number of measurements: 19
# Mean voltage: -0.729426 V
# Standard deviation: ±0.023485 V
# Variance: 0.00055153 V²
# Range: [-0.787696, -0.708155] V
# Median: -0.718764 V
# Coefficient of variation: -3.22%
# Shapiro-Wilk normality test: p = 0.0008
#   -> Data may not be normally distributed (p ≤ 0.05)
# Plot saved as: iv_analysis_plots/voltage_analysis_I_0.319802A.png
# Found 19 voltage measurements
# Voltage statistics: -0.729426 ± 0.023485 V
# Voltage data saved as: iv_analysis_plots/voltages_I_0.319802A.txt
# Cycle data saved as: iv_analysis_plots/cycle_data_I_0.319802A.txt
#
# === Comparing Multiple Current Values ===
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Cycle 0: Found voltage = -1.197386 V for current = 0.010563 A
# Cycle 1: Found voltage = -1.197149 V for current = 0.010563 A
# Cycle 2: Found voltage = -1.197594 V for current = 0.010563 A
# Cycle 3: Found voltage = -1.197274 V for current = 0.010563 A
# Cycle 4: Found voltage = -1.197432 V for current = 0.010563 A
# Cycle 5: Found voltage = -1.196327 V for current = 0.010563 A
# Cycle 6: Found voltage = -1.197481 V for current = 0.010563 A
# Cycle 7: Found voltage = -1.197078 V for current = 0.010563 A
# Cycle 8: Found voltage = -1.197686 V for current = 0.010563 A
# Cycle 9: Found voltage = -1.197197 V for current = 0.010563 A
# Cycle 10: Found voltage = -1.197422 V for current = 0.010563 A
# Cycle 11: Found voltage = -1.196912 V for current = 0.010563 A
# Cycle 12: Found voltage = -1.197768 V for current = 0.010563 A
# Cycle 13: Found voltage = -1.197366 V for current = 0.010563 A
# Cycle 14: Found voltage = -1.197355 V for current = 0.010563 A
# Cycle 15: Found voltage = -1.197481 V for current = 0.010563 A
# Cycle 16: Found voltage = -1.197986 V for current = 0.010563 A
# Cycle 17: Found voltage = -1.197596 V for current = 0.010563 A
# Cycle 18: Found voltage = -1.199409 V for current = 0.010563 A
# Cycle 19: Found voltage = -1.199694 V for current = 0.010563 A
#
# === Statistical Analysis for Current = 0.010563 A ===
# Number of measurements: 20
# Mean voltage: -1.197580 V
# Standard deviation: ±0.000758 V
# Variance: 0.00000057 V²
# Range: [-1.199694, -1.196327] V
# Median: -1.197427 V
# Coefficient of variation: -0.06%
# Shapiro-Wilk normality test: p = 0.0005
#   -> Data may not be normally distributed (p ≤ 0.05)
# Plot saved as: iv_analysis_plots/voltage_analysis_I_0.010563A.png
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Cycle 0: Found voltage = -0.943734 V for current = 0.165183 A
# Cycle 1: Found voltage = -0.978309 V for current = 0.165183 A
# Cycle 2: Found voltage = -0.983253 V for current = 0.165183 A
# Cycle 3: Found voltage = -0.963965 V for current = 0.165183 A
# Cycle 4: Found voltage = -0.966374 V for current = 0.165183 A
# Cycle 5: Found voltage = -0.951787 V for current = 0.165183 A
# Cycle 6: Found voltage = -0.959649 V for current = 0.165183 A
# Cycle 7: Found voltage = -0.959739 V for current = 0.165183 A
# Cycle 8: Found voltage = -0.958050 V for current = 0.165183 A
# Cycle 9: Found voltage = -0.963719 V for current = 0.165183 A
# Cycle 10: Found voltage = -0.964368 V for current = 0.165183 A
# Cycle 11: Found voltage = -0.967416 V for current = 0.165183 A
# Cycle 12: Found voltage = -0.969318 V for current = 0.165183 A
# Cycle 13: Found voltage = -0.962458 V for current = 0.165183 A
# Cycle 14: Found voltage = -0.962590 V for current = 0.165183 A
# Cycle 15: Found voltage = -0.963571 V for current = 0.165183 A
# Cycle 16: Found voltage = -0.977944 V for current = 0.165183 A
# Cycle 17: Found voltage = -0.990396 V for current = 0.165183 A
# Cycle 18: Found voltage = -1.005273 V for current = 0.165183 A
# Cycle 19: Found voltage = -1.007319 V for current = 0.165183 A
#
# === Statistical Analysis for Current = 0.165183 A ===
# Number of measurements: 20
# Mean voltage: -0.969962 V
# Standard deviation: ±0.016252 V
# Variance: 0.00026413 V²
# Range: [-1.007319, -0.943734] V
# Median: -0.964166 V
# Coefficient of variation: -1.68%
# Shapiro-Wilk normality test: p = 0.0251
#   -> Data may not be normally distributed (p ≤ 0.05)
# Plot saved as: iv_analysis_plots/voltage_analysis_I_0.165183A.png
# Detected 20 measurement cycles with 100 points each
# V1 range: [-1.500, -0.510] V
# Current range: [0.000563, 0.639042] A
# Warning: Target current 0.3198025 is outside the measured range [0.000621, 0.318944]
# Cycle 1: Found voltage = -0.725955 V for current = 0.319802 A
# Cycle 2: Found voltage = -0.750380 V for current = 0.319802 A
# Cycle 3: Found voltage = -0.714186 V for current = 0.319802 A
# Cycle 4: Found voltage = -0.715451 V for current = 0.319802 A
# Cycle 5: Found voltage = -0.708269 V for current = 0.319802 A
# Cycle 6: Found voltage = -0.715169 V for current = 0.319802 A
# Cycle 7: Found voltage = -0.710834 V for current = 0.319802 A
# Cycle 8: Found voltage = -0.713357 V for current = 0.319802 A
# Cycle 9: Found voltage = -0.715785 V for current = 0.319802 A
# Cycle 10: Found voltage = -0.716539 V for current = 0.319802 A
# Cycle 11: Found voltage = -0.727571 V for current = 0.319802 A
# Cycle 12: Found voltage = -0.725808 V for current = 0.319802 A
# Cycle 13: Found voltage = -0.730063 V for current = 0.319802 A
# Cycle 14: Found voltage = -0.708155 V for current = 0.319802 A
# Cycle 15: Found voltage = -0.718764 V for current = 0.319802 A
# Cycle 16: Found voltage = -0.748250 V for current = 0.319802 A
# Cycle 17: Found voltage = -0.743470 V for current = 0.319802 A
# Cycle 18: Found voltage = -0.787696 V for current = 0.319802 A
# Cycle 19: Found voltage = -0.783388 V for current = 0.319802 A
#
# === Statistical Analysis for Current = 0.319802 A ===
# Number of measurements: 19
# Mean voltage: -0.729426 V
# Standard deviation: ±0.023485 V
# Variance: 0.00055153 V²
# Range: [-0.787696, -0.708155] V
# Median: -0.718764 V
# Coefficient of variation: -3.22%
# Shapiro-Wilk normality test: p = 0.0008
#   -> Data may not be normally distributed (p ≤ 0.05)
# Plot saved as: iv_analysis_plots/voltage_analysis_I_0.319802A.png
# Comparison plot saved as: iv_analysis_plots/current_comparison.png
# === Comparison Table ===
# Current (A)  Mean (V)     Std (V)      Variance (V²)   CV (%)   N
# ----------------------------------------------------------------------
# 0.010563     -1.197580    0.000758     0.00000057      -0.06    20
# 0.165183     -0.969962    0.016252     0.00026413      -1.68    20
# 0.319802     -0.729426    0.023485     0.00055153      -3.22    19
# Statistical summary saved as: iv_analysis_plots/statistical_summary.csv
#
# === Analysis Complete ===
# All plots and data have been saved to the 'iv_analysis_plots' directory
# Files generated:
# - Individual voltage analysis plots for each current
# - Comparison plot across multiple currents
# - Statistical summary CSV file
# - Individual voltage data text files
